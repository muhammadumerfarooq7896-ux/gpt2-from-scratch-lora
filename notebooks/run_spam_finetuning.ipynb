# %% [markdown]
# # Spam Fine-Tuning — Run Notebook

# %% [markdown]
# ## 1. Mount Drive (for the dataset only)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## 2. Install dependencies

# %%
# !pip install -q tiktoken

# %%
# !ls *.py
# Out:
# architecture.py       LoRA.py			 run_lora_spam.py
# gpt2_downloader.py    run_frozen_spam.py
# instantiate_model.py  run_full_finetune_spam.py

# %% [markdown]
# ## 4. Run: Frozen

# %%
# !python run_frozen_spam.py
# Out:
# 2026-08-28 04:55:11.255481: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# checkpoint: 100% 77.0/77.0 [00:00<00:00, 344kiB/s]
# encoder.json: 100% 1.04M/1.04M [00:01<00:00, 582kiB/s]
# hparams.json: 100% 90.0/90.0 [00:00<00:00, 363kiB/s]
# model.ckpt.data-00000-of-00001: 100% 498M/498M [03:01<00:00, 2.74MiB/s]
# model.ckpt.index: 100% 5.21k/5.21k [00:00<00:00, 19.1MiB/s]
# model.ckpt.meta: 100% 471k/471k [00:01<00:00, 386kiB/s]
# vocab.bpe: 100% 456k/456k [00:01<00:00, 375kiB/s]
# Trainable params: 1,538 / 124,441,346 (0.0012%)
# Epoch 1/4 | train loss 0.7223 | val acc 0.4899
# Epoch 2/4 | train loss 0.6047 | val acc 0.8188
# Epoch 3/4 | train loss 0.5337 | val acc 0.7919
# Epoch 4/4 | train loss 0.5008 | val acc 0.7315
#
# ...

# %% [markdown]
# ## 5. Run: LoRA

# %%
# !python run_lora_spam.py
# Out:
# 2026-08-28 05:00:05.979299: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# File already exists and is up-to-date: gpt2_weights/124M/checkpoint
# File already exists and is up-to-date: gpt2_weights/124M/encoder.json
# File already exists and is up-to-date: gpt2_weights/124M/hparams.json
# File already exists and is up-to-date: gpt2_weights/124M/model.ckpt.data-00000-of-00001
# File already exists and is up-to-date: gpt2_weights/124M/model.ckpt.index
# File already exists and is up-to-date: gpt2_weights/124M/model.ckpt.meta
# File already exists and is up-to-date: gpt2_weights/124M/vocab.bpe
# Trainable params: 1,328,642 / 125,768,450 (1.056%)
# Epoch 1/4 | train loss 0.6824 | val acc 0.8322
# Epoch 2/4 | train loss 0.3132 | val acc 0.9396
# ...

# %% [markdown]
# ## 6. Run: Full fine-tune

# %%
# !python run_full_finetune_spam.py
# Out:
# 2026-08-28 05:02:18.925969: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# File already exists and is up-to-date: gpt2_weights/124M/checkpoint
# File already exists and is up-to-date: gpt2_weights/124M/encoder.json
# File already exists and is up-to-date: gpt2_weights/124M/hparams.json
# File already exists and is up-to-date: gpt2_weights/124M/model.ckpt.data-00000-of-00001
# File already exists and is up-to-date: gpt2_weights/124M/model.ckpt.index
# File already exists and is up-to-date: gpt2_weights/124M/model.ckpt.meta
# File already exists and is up-to-date: gpt2_weights/124M/vocab.bpe
# Trainable params: 124,441,346 / 124,441,346 (100.00%)
# Epoch 1/4 | train loss 0.5602 | val acc 0.8725
# ...

# %% [markdown]
# ## 7. Confirm results saved to Drive

# %%
# !ls /content/drive/MyDrive/llm_finetune_project/results/spam/
# !ls /content/drive/MyDrive/llm_finetune_project/checkpoints/spam/
# Out:
# frozen_metrics.json  full_finetune_metrics.json  lora_metrics.json
# frozen_spam.pt	full_finetune_spam.pt  lora_spam.pt
