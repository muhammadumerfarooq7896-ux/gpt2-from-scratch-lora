# %% [markdown]
# # IMDB Fine-Tuning — Run Notebook

# %% [markdown]
# ## 1. Mount Drive (for the dataset only)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## 2. Install dependencies

# %%
# !pip install -q tiktoken scikit-learn joblib

# %%
# !ls *.py
# Out:
# architecture.py       lora.py			 run_lora_imdb.py
# gpt2_downloader.py    run_frozen_imdb.py	 train_tfidf_imdb.py
# instantiate_model.py  run_full_finetune_imdb.py

# %% [markdown]
# ## 4. Run: Frozen

# %%
# !python run_frozen_imdb.py
# Out:
# 2026-08-28 05:35:23.696635: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# checkpoint: 100% 77.0/77.0 [00:00<00:00, 311kiB/s]
# encoder.json: 100% 1.04M/1.04M [00:00<00:00, 3.07MiB/s]
# hparams.json: 100% 90.0/90.0 [00:00<00:00, 464kiB/s]
# model.ckpt.data-00000-of-00001: 100% 498M/498M [00:37<00:00, 13.2MiB/s]
# model.ckpt.index: 100% 5.21k/5.21k [00:00<00:00, 19.3MiB/s]
# model.ckpt.meta: 100% 471k/471k [00:00<00:00, 2.02MiB/s]
# vocab.bpe: 100% 456k/456k [00:00<00:00, 1.82MiB/s]
# Trainable params: 1,538 / 124,441,346 (0.0012%)
# Epoch 1/4 | train loss 0.7027 | val acc 0.6280
# Epoch 2/4 | train loss 0.5801 | val acc 0.6740
# Epoch 3/4 | train loss 0.5379 | val acc 0.6560
# Epoch 4/4 | train loss 0.5436 | val acc 0.6740
#
# ...

# %% [markdown]
# ## 5. Run: LoRA

# %%
# !python run_lora_imdb.py
# Out:
# 2026-08-28 05:38:01.623209: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# File already exists and is up-to-date: gpt2_weights/124M/checkpoint
# File already exists and is up-to-date: gpt2_weights/124M/encoder.json
# File already exists and is up-to-date: gpt2_weights/124M/hparams.json
# File already exists and is up-to-date: gpt2_weights/124M/model.ckpt.data-00000-of-00001
# File already exists and is up-to-date: gpt2_weights/124M/model.ckpt.index
# File already exists and is up-to-date: gpt2_weights/124M/model.ckpt.meta
# File already exists and is up-to-date: gpt2_weights/124M/vocab.bpe
# Trainable params: 1,328,642 / 125,768,450 (1.056%)
# Epoch 1/4 | train loss 0.6755 | val acc 0.8260
# Epoch 2/4 | train loss 0.3287 | val acc 0.7960
# ...

# %% [markdown]
# ## 6. Run: Full fine-tune

# %%
# !python run_full_finetune_imdb.py
# Out:
# 2026-08-28 05:42:26.939108: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# File already exists and is up-to-date: gpt2_weights/124M/checkpoint
# File already exists and is up-to-date: gpt2_weights/124M/encoder.json
# File already exists and is up-to-date: gpt2_weights/124M/hparams.json
# File already exists and is up-to-date: gpt2_weights/124M/model.ckpt.data-00000-of-00001
# File already exists and is up-to-date: gpt2_weights/124M/model.ckpt.index
# File already exists and is up-to-date: gpt2_weights/124M/model.ckpt.meta
# File already exists and is up-to-date: gpt2_weights/124M/vocab.bpe
# Trainable params: 124,441,346 / 124,441,346 (100.00%)
# Epoch 1/4 | train loss 0.7186 | val acc 0.7180
# ...

# %% [markdown]
# ## 7. Run: TF-IDF baseline

# %%
# !python train_tfidf_imdb.py
# Out:
# Vocabulary size (TF-IDF features): 5,000
# Logistic regression coefficients: 5,000
# Test accuracy: 0.9060
# Training time: 0.55s
# Saved TF-IDF + LogisticRegression checkpoint to /content/drive/MyDrive/llm_finetune_project/checkpoints/imdb/tfidf_imdb.joblib (0.2134 MB)
#
# Saved metrics to /content/drive/MyDrive/llm_finetune_project/results/imdb/tfidf_metrics.json

# %% [markdown]
# ## 8. Confirm results saved to Drive

# %%
# !ls /content/drive/MyDrive/llm_finetune_project/results/imdb/
# !ls /content/drive/MyDrive/llm_finetune_project/checkpoints/imdb/
# Out:
# frozen_metrics.json	    lora_metrics.json
# full_finetune_metrics.json  tfidf_metrics.json
# frozen_imdb.pt	full_finetune_imdb.pt  lora_imdb.pt  tfidf_imdb.joblib
